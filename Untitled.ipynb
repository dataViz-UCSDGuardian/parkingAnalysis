# %%
import pandas as ps
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='hali96', api_key='y8861qxd0n')

# %%
fall2015 = ps.read_excel(open('falldata.xls', 'rb'), sheetname='By Structure')

hopkins = []
pang = []
torpinS = []
torpinN = [] 
gilman = []
eastC1E = []
eastC1W = []
arbor = []
bachman = []
arbor140 = [] 

for i in range (3, 13):
    hopkins.append(fall2015.ix[7][i])
    pang.append(fall2015.ix[18][i])
    torpinS.append(fall2015.ix[29][i])
    torpinN.append(fall2015.ix[40][i])
    gilman.append(fall2015.ix[52][i])

print(hopkins)
print(pang)
print(torpinS)
print(torpinN)
print(gilman)

almostdone = [hopkins, pang, torpinS, torpinN, gilman]

almostdone
# Out:
# [16, 0, 0, 1, 0, 1, 4, 1, 4, 16]
# [29, 5, 0, 0, 0, 0, 1, 1, 7, 11]
# [4, 3, 2, 1, 1, 2, 2, 2, 3, 3]
# [5, 4, 0, 0, 1, 1, 1, 0, 2, 3]
# [126, 62, 3, 0, 0, 0, 0, 22, 22, 44]
# [[16, 0, 0, 1, 0, 1, 4, 1, 4, 16],
#  [29, 5, 0, 0, 0, 0, 1, 1, 7, 11],
#  [4, 3, 2, 1, 1, 2, 2, 2, 3, 3],
#  [5, 4, 0, 0, 1, 1, 1, 0, 2, 3],
#  [126, 62, 3, 0, 0, 0, 0, 22, 22, 44]]

# %%
fall2015
# Out:
#     University of California, San Diego Survey of Parking Space Occupancy Levels, Fall 2015  \
# 0                                         By Structure
# 1                                                  NaN
# 2                                            Structure
# 3                                                  NaN
# 4                                                  NaN
# 5                                              Hopkins
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                              Pangea
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                              Torrey
# 28                                               Pines
# 29                                              Center
# ..                                                 ...
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                             Bachman
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                          140 Arbor
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
#
#        Unnamed: 1 Unnamed: 2                    Unnamed: 3 Unnamed: 4  \
# 0             NaN        NaN                           NaN        NaN
# 1             NaN        NaN                           NaN        NaN
# 2         Parking    Parking  Average Empty Parking Spaces        NaN
# 3           Space     Spaces                          8:00       9:00
# 4             NaN        NaN                            am         am
# 5               A         80                            68         57
# 6               B        495                           421        291
# 7               S        674                            16          0
# 8         Visitor         92                            80         69
# 9        Reserved          1                             1          0
# 10      Allocated         18                            15         13
# 11     Accessible         25                            22         19
# 12     UC Vehicle         10                             3          2
# 13   Service Yard        NaN                           NaN        NaN
# 14        Loading        NaN                           NaN        NaN
# 15          Total       1395                           626        451
# 16              A         80                            60         55
# 17              B        185                           114         89
# 18              S        550                            29          5
# 19        Visitor        109                           104         99
# 20       Reserved          8                             4          4
# 21      Allocated          6                             2          3
# 22     Accessible         15                            11         10
# 23     UC Vehicle          8                             3          4
# 24   Service Yard        NaN                           NaN        NaN
# 25        Loading        NaN                           NaN        NaN
# 26          Total        961                           327        269
# 27              A        NaN                           NaN        NaN
# 28              B        392                           208        121
# 29              S          4                             4          3
# ..            ...        ...                           ...        ...
# 85        Visitor        273                           175        136
# 86       Reserved         19                            17         17
# 87      Allocated          8                             6          4
# 88     Accessible         15                             2          2
# 89     UC Vehicle        NaN                           NaN        NaN
# 90   Service Yard        NaN                           NaN        NaN
# 91        Loading        NaN                           NaN        NaN
# 92          Total        553                           381        302
# 93              A        NaN                           NaN        NaN
# 94              B       1000                           270         91
# 95              S        NaN                           NaN        NaN
# 96        Visitor        NaN                           NaN        NaN
# 97       Reserved        NaN                           NaN        NaN
# 98      Allocated         26                            21         20
# 99     Accessible          6                             4          4
# 100    UC Vehicle        NaN                           NaN        NaN
# 101  Service Yard        NaN                           NaN        NaN
# 102       Loading        NaN                           NaN        NaN
# 103         Total       1032                           295        115
# 104             A          9                             9          8
# 105             B         21                            12          8
# 106             S        NaN                           NaN        NaN
# 107       Visitor        NaN                           NaN        NaN
# 108      Reserved          4                             4          4
# 109     Allocated         42                            42         41
# 110    Accessible          4                             4          3
# 111    UC Vehicle        NaN                           NaN        NaN
# 112  Service Yard        NaN                           NaN        NaN
# 113       Loading        NaN                           NaN        NaN
# 114         Total         80                            71         64
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0          NaN        NaN        NaN        NaN        NaN         NaN
# 1          NaN        NaN        NaN        NaN        NaN         NaN
# 2          NaN        NaN        NaN        NaN        NaN         NaN
# 3        10:00      11:00      12:00       1:00       2:00        3:00
# 4           am         am         pm         pm         pm          pm
# 5           37         25         16         15          9          13
# 6          119          9          0          2          4          13
# 7            0          1          0          1          4           1
# 8           42         21          5         11         19          20
# 9            0          0          0          0          0           0
# 10           9          4          3          4          4           4
# 11          18         19         13         16         18          19
# 12           3          3          3          4          3           4
# 13         NaN        NaN        NaN        NaN        NaN         NaN
# 14         NaN        NaN        NaN        NaN        NaN         NaN
# 15         228         82         40         53         61          74
# 16          45         24         13         10         10          14
# 17          29          0          1          1          3           9
# 18           0          0          0          0          1           1
# 19          79         45         20         13         21          23
# 20           5          4          5          5          5           5
# 21           2          2          1          2          1           2
# 22          10          8          8          9          7           7
# 23           4          4          1          2          4           2
# 24         NaN        NaN        NaN        NaN        NaN         NaN
# 25         NaN        NaN        NaN        NaN        NaN         NaN
# 26         174         87         49         42         52          63
# 27         NaN        NaN        NaN        NaN        NaN         NaN
# 28          65         55         64         75         66          64
# 29           2          1          1          2          2           2
# ..         ...        ...        ...        ...        ...         ...
# 85          88         65         67         77         68          69
# 86          15         15         14         14         14          17
# 87           5          5          3          5          4           5
# 88           1          2          2          4          3           3
# 89         NaN        NaN        NaN        NaN        NaN         NaN
# 90         NaN        NaN        NaN        NaN        NaN         NaN
# 91         NaN        NaN        NaN        NaN        NaN         NaN
# 92         213        168        160        171        159         171
# 93         NaN        NaN        NaN        NaN        NaN         NaN
# 94          31         14         20         24         27          71
# 95         NaN        NaN        NaN        NaN        NaN         NaN
# 96         NaN        NaN        NaN        NaN        NaN         NaN
# 97         NaN        NaN        NaN        NaN        NaN         NaN
# 98          19         13         12         10         12           7
# 99           3          2          3          3          3           2
# 100        NaN        NaN        NaN        NaN        NaN         NaN
# 101        NaN        NaN        NaN        NaN        NaN         NaN
# 102        NaN        NaN        NaN        NaN        NaN         NaN
# 103         53         29         35         37         42          80
# 104          7          7          6          7          6           5
# 105          4          4          4          4          5           6
# 106        NaN        NaN        NaN        NaN        NaN         NaN
# 107        NaN        NaN        NaN        NaN        NaN         NaN
# 108          3          3          3          3          3           3
# 109         37         31         27         26         23          26
# 110          3          3          3          3          3           3
# 111        NaN        NaN        NaN        NaN        NaN         NaN
# 112        NaN        NaN        NaN        NaN        NaN         NaN
# 113        NaN        NaN        NaN        NaN        NaN         NaN
# 114         54         48         43         43         40          43
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0           NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN     At Peak         NaN         NaN
# 3          4:00        5:00       Empty    Occupied           %
# 4            pm          pm      Spaces      Spaces    Occupied
# 5            20          26           9          71      0.8875
# 6            43         129           0         495           1
# 7             4          16           0         674           1
# 8            30          38           5          87    0.945652
# 9             0           0           0           1           1
# 10            5           6           3          15    0.833333
# 11           17          19          13          12        0.48
# 12            5           4           2           8         0.8
# 13          NaN         NaN         NaN         NaN         NaN
# 14          NaN         NaN         NaN         NaN         NaN
# 15          124         238          40        1355    0.971326
# 16           21          32          10          70       0.875
# 17           24          55           0         185           1
# 18            7          11           0         550           1
# 19           48          58          13          96    0.880734
# 20            4           4           4           4         0.5
# 21            3           2           1           5    0.833333
# 22            9           9           7           8    0.533333
# 23            3           3           1           7       0.875
# 24          NaN         NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN         NaN
# 26          119         174          42         919    0.956296
# 27          NaN         NaN         NaN         NaN         NaN
# 28          134         248          55         337    0.859694
# 29            3           3           1           3        0.75
# ..          ...         ...         ...         ...         ...
# 85           94         121          65         208    0.761905
# 86           13          15          13           6    0.315789
# 87            5           6           3           5       0.625
# 88            5           6           1          14    0.933333
# 89          NaN         NaN         NaN         NaN         NaN
# 90          NaN         NaN         NaN         NaN         NaN
# 91          NaN         NaN         NaN         NaN         NaN
# 92          200         258         159         394    0.712477
# 93          NaN         NaN         NaN         NaN         NaN
# 94          214         409          14         986       0.986
# 95          NaN         NaN         NaN         NaN         NaN
# 96          NaN         NaN         NaN         NaN         NaN
# 97          NaN         NaN         NaN         NaN         NaN
# 98            7           6           6          20    0.769231
# 99            4           6           2           4    0.666667
# 100         NaN         NaN         NaN         NaN         NaN
# 101         NaN         NaN         NaN         NaN         NaN
# 102         NaN         NaN         NaN         NaN         NaN
# 103         225         421          29        1003    0.971899
# 104           5           6           5           4    0.444444
# 105          10          11           4          17    0.809524
# 106         NaN         NaN         NaN         NaN         NaN
# 107         NaN         NaN         NaN         NaN         NaN
# 108           3           3           3           1        0.25
# 109          28          36          23          19    0.452381
# 110           3           4           3           1        0.25
# 111         NaN         NaN         NaN         NaN         NaN
# 112         NaN         NaN         NaN         NaN         NaN
# 113         NaN         NaN         NaN         NaN         NaN
# 114          49          60          40          40         0.5
#
# [115 rows x 16 columns]

# %%
index = ["Hopkins", "Pangea", "Torrey Pines Center South", "Torrey Pines Center North", "Gilman"]
columns = ["8am", "9am", "10am", "11am", "12pm", "1pm", "2pm", "3pm", "4pm", "5pm"]

# %%
Sspots = ps.DataFrame(almostdone, index=index, columns=columns)
Sspots
# Out:
#                            8am  9am  10am  11am  12pm  1pm  2pm  3pm  4pm  5pm
# Hopkins                     16    0     0     1     0    1    4    1    4   16
# Pangea                      29    5     0     0     0    0    1    1    7   11
# Torrey Pines Center South    4    3     2     1     1    2    2    2    3    3
# Torrey Pines Center North    5    4     0     0     1    1    1    0    2    3
# Gilman                     126   62     3     0     0    0    0   22   22   44

# %%
data = [go.Heatmap(z = almostdone, x = columns, y = index, zmax = 2000, 
                  colorscale = 'PRGn')]
py.iplot(data, filename='WeAreDone')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~hali96/0 or inside your plot.ly account where it is named 'WeAreDone'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hali96/0.embed" height="525px" width="100%"></iframe>
